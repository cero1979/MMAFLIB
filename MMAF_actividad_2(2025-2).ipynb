# %% [markdown]
# # 2. Poda en un parque de Cali

# %% [markdown]
# ## 2.1 Contexto

# %% [markdown]
# Cada semana, la cuadrilla de mantenimiento de zonas verdes de la Alcaldía de Santiago de Cali realiza la poda de los prados en el Parque El Ingenio . Con el fin de conservar polinizadores y aves pequeñas, la autoridad ambiental decide dejar sin intervenir una zona central de cada prado para que funcione como microhábitat. Esta tarea es fundamental para la conservación de la biodiversidad urbana y asegurar la salud de los ecosistemas locales.Esta es una tarea que requiere precisión y cuidado, ya que la poda debe realizarse de manera uniforme y respetando las áreas designadas para la biodiversidad. Tal tarea se lleva a cabo en otros parques de la ciudad, como el Parque de los Gatos y el Parque de la Flora, donde también se implementan prácticas similares para proteger la fauna local..

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.2 Tema
#
# Factorización y productos notables
#
# ## 2.3  Objetivo
#
# Construir una estrategia para determinar la equivalencia entre dos expresiones algebraicas que corresponden a áreas de sectores de un parque.

# %% [markdown]
# ## 2.4 Actividad

# %% [markdown]
# ### 2.4.1  Poda de un sector cuadrado del parque
#
# En una plazoleta del Parque El Ingenio hay un prado cuadrado de lado $b$ metros. Siguiendo la pauta de manejo, la cuadrilla poda una franja perimetral uniforme de ancho $x$ metros a lo largo de todo el contorno y deja sin podar el cuadrado central como refugio de biodiversidad. El prado mide  $b\times b$ y la franja podada tiene ancho
# $x$ en cada lado; el área central sin podar es un cuadrado.

# %% [markdown]
# ![diagrama_b_x.png](data:image/png;base64,...)

# %% [markdown]
# Sabiendo que el área de un cuadrado de lado $b$ corresponde a
# $$A_b=b^2$$
# uno de los ingenieros ambientales de la cuadrilla infiere que el área de la parte podada es $b^2-(b-2x)^2$. Tu objetivo es ayudar a este ingeniero a comprobar si su inferencia es correcta.

# %% [markdown]
# #### 2.4.1.1 Manos a la obra

# %% [markdown]
# 1. **Comprender el problema.** En esta etapa se busca comprender bien el problema que se quiere resolver e identificar las variables, datos y reglas relevantes para solucionar el problema. Descríbelos.

# %% [markdown]
# 3. **Ejecutar el plan.** En esta etapa deberías ejecutar la estrategia identificada en el paso anterior usando herramientas matemáticas, posiblemente asistidas por software.

# %% [markdown]
# 4. **Examinar la solución obtenida** Siempre que encuentres una solución de un problema es importante asegurarte que los resultados obtenido sean acordes  a las condiciones  iniciales del problema, factibles y en el caso contrario deberías regresar el primer paso.

# %% [markdown]
# ### 2.4.2 Jugando con el computador!
# En esta actividad, explorarás el cálculo del volumen de una tubería utilizando la fórmula:
#
# $$
# V_{tuberia} = \pi R^2l - \pi r^2l
# $$
#
# Es importante manipular correctamente la diferencia de cuadrados para evitar errores comunes. Uno de los **errores frecuentes** es asumir incorrectamente que:
#
# $$
# a^2 - b^2 = (a - b)^2
# $$
#
# ¿Cómo podemos comprobar que esta igualdad no se cumple? ¡Podemos verificarlo con la ayuda de un computador!

# %% [markdown]
# #### 2.4.2.1 Manos a la obra

# %% [markdown]
# 1. **Comprender el problema.** En esta etapa se busca comprender bien el problema que se quiere resolver e identificar las variables, datos y reglas relevantes para solucionar el problema. Descríbelos.

# %% [markdown]
# 2. **Planear la solución.** En esta etapa deberías identificar los pasos necesarios para resolver el problema y seleccionar la mejor estrategia para hacerlo.

# %% [markdown]
# a. Si calculas $\pi (R^2 - r^2) l $ correctamente y lo comparas con $\pi (R - r)^2 l $, ¿cuál es la diferencia en los resultados? Usa un ejemplo con valores numéricos.
#
# b. ¿Por qué $\pi (R - r)^2 l$ no es equivalente a $ \pi R^2l - \pi r^2l $? Justifica tu respuesta explorando la expansión algebraica.
#
# c. ¿Cómo cambia la magnitud del error al incrementar la diferencia entre $R$ y $r$? Prueba con distintos valores de $R$ y $r$.
#
# d. En un caso límite donde $r = 0$ , ¿cómo se comporta la fórmula? ¿Persiste el error en este caso?

# %% [markdown]
# 3. **Ejecutar el plan.** En esta etapa deberías ejecutar la estrategia identificada en el paso anterior usando herramientas matemáticas, posiblemente asistidas por software.

# %% [markdown]
# 4. **Examinar la solución obtenida** Siempre que encuentres una solución de un problema es importante asegurarte que los resultados obtenido sean acordes  a las condiciones  iniciales del problema, factibles y en el caso contrario deberías regresar el primer paso.

# %% [markdown]
# ### Reflexión
#
# 1. Cambia los valores de los parámetros y observa cómo varía la diferencia entre los cálculos.
# 2. Responde las preguntas planteadas en las celdas anteriores utilizando la función `analizar_diferencia_cuadrados` de la librería del curso. Recuerda que solo debes modificar los parámetros.

# %%
import requests
url = "https://raw.githubusercontent.com/cero1979/MMAFLIB/main/MMAF2025_2.py"
response = requests.get(url)
with open("MMAF2025_2.py", "w", encoding="utf-8") as f:
    f.write(response.text)

from MMAF2025_2 import podar_campo_demo
podar_campo_demo()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (<Figure size 800x600 with 4 Axes>,
# ...
#  <matplotlib.widgets.Slider at 0x1167b20f0>)

# %%
from MMAF import analizar_diferencia_cuadrados
# === Parámetros iniciales (Modifica solo estos valores) ===
radio_exterior = 5  # Radio del cilindro exterior (en metros)
radio_interior = 3  # Radio del cilindro interior (en metros)
altura = 10         # Altura del cilindro (en metros)

# Llamar a la función
analizar_diferencia_cuadrados(radio_exterior, radio_interior, altura)
# Out:
# === Resultados ===
# Radio exterior (R): 5 m
# Radio interior (r): 3 m
# Altura (h): 10 m
#
# --- Cálculo correcto ---
# Volumen correcto (π(R² - r²)h): 502.65 m³
#
# --- Cálculo erróneo ---
# Volumen erróneo (π(R - r)²h): 125.66 m³
#
# --- Diferencia entre ambos ---
# Diferencia: 376.99 m³

# %%
import requests
url = "https://raw.githubusercontent.com/cero1979/MMAFLIB/main/codact2.py"
response = requests.get(url)
with open("codact2.py", "w", encoding="utf-8") as file:
    file.write(response.text)

# %matplotlib widget
from codact2 import podar_campo_demo
podar_campo_demo()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (<Figure size 800x600 with 4 Axes>,
# ...
#  <matplotlib.widgets.Slider at 0x116cbdfa0>)
